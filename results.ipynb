# %% [markdown]
# # Общий план
#
# ## 1. Запустим Parler-TTS на тестовом примере (пример в ноутбуке results.ipynb).
#
#
# Note: изначально непонятно, какая часть всей выборки использовалась для претрейна, который выложен на huggingface. Поэтому также будем сравнивать на LibriSpeech test clean для объективности.
#
# Разделим датасет Jenny на тренировочный и тестовый наборы: выделим под тестовую часть ~0.3% (в итоге 63 случайных аудиозаписей из набора).
#
# Также возьмем небольшую часть датасета LibriSpeech test clean (63 случайных аудиозаписей). (всё проделано в ноутбуке results.ipynb)
#
# Все расчеты проводятся на одной T4 GPU (поэтому для бенчмарков используем немного записей).
#
# ## 2. Что входит в оценку синтеза речи
#
# Нам важно учитывать характеристики:
#
# - Естественность (Naturalness)
#
# - Разборчивость (Intelligibility): Насколько четко произносятся слова.
#
# - Сходство голосов: насколько синтезированный голос похож на целевой.
#
# ## 3. Метрики для оценки
#
# Для каждой характеристики будем использовать следующие метрики:
#
# - Естественность: MOS (Mean Opinion Score) — субъективная оценка от 1 до 5, где 5 — максимальная естественность (обычно оценивается людьми, что очень субьективно). Также есть разные Neural MOS, к примеру [UTMOS](https://arxiv.org/abs/2204.02152), будем использовать его.
# - Разборчивость: WER (Word Error Rate) — процент ошибок в распознавании слов. Будем брать хороший ASR, полученное аудио транскрибировать и сравнивать с исходной транскрибацией.
#
# - Сходство голосов: будем считать [Speaker Encoder Cosine Similarity - SECS](https://arxiv.org/abs/2104.05557), используя модель эмбеддингов WavLM
#
# Почему именно эти метрики? Они являются наиболее объективными для TTS, хотя и тут вопросы: какой ASR использовать для WER, какую именно модель для Neural MOS лучше использовать, из-за этого во многих публикациях могут быть различия в оценках и не будет объективности.
#
# Можно также было бы оценивать более субъективные вещи: вручную и/или попросить группу людей сделать оценку MOS, также насколько точно передается стиль тона в промпте Parler TTS, но это не сильно точно.

# %%
# !git clone https://github.com/Nikait/Parler_TTS_estimation
# !mv Parler_TTS_estimation/compute_utmos.py ./compute_utmos.py
# !mv Parler_TTS_estimation/compute_wer.py ./compute_wer.py
# !mv Parler_TTS_estimation/compute_secs.py ./compute_secs.py

# %% [markdown]
# # пример запуска

# %%
# !pip install git+https://github.com/huggingface/parler-tts.git
# Out:
# Collecting git+https://github.com/huggingface/parler-tts.git
#   Cloning https://github.com/huggingface/parler-tts.git to /tmp/pip-req-build-pepp9cte
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/parler-tts.git /tmp/pip-req-build-pepp9cte
#   Resolved https://github.com/huggingface/parler-tts.git to commit d108732cd57788ec86bc857d99a6cabd66663d68
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting descript-audiotools@ git+https://github.com/descriptinc/audiotools (from parler_tts==0.2.2)
#   Cloning https://github.com/descriptinc/audiotools to /tmp/pip-install-ykq24jmo/descript-audiotools_cacd0e69259f451081dc6f5b2fb41f99
#   Running command git clone --filter=blob:none --quiet https://github.com/descriptinc/audiotools /tmp/pip-install-ykq24jmo/descript-audiotools_cacd0e69259f451081dc6f5b2fb41f99
#   Resolved https://github.com/descriptinc/audiotools to commit 348ebf2034ce24e2a91a553e3171cb00c0c71678
#   Preparing metadata (setup.py) ... done
# Collecting transformers<=4.46.1,>=4.46.1 (from parler_tts==0.2.2)
#   Downloading transformers-4.46.1-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from parler_tts==0.2.2) (2.5.1+cu121)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from parler_tts==0.2.2) (0.2.0)
# Collecting descript-audio-codec (from parler_tts==0.2.2)
#   Downloading descript_audio_codec-1.0.0-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: protobuf>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from parler_tts==0.2.2) (4.25.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (0.27.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (0.4.5)
# Collecting tokenizers<0.21,>=0.20 (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2)
#   Downloading tokenizers-0.20.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (4.67.1)
# Collecting argbind>=0.3.7 (from descript-audio-codec->parler_tts==0.2.2)
#   Downloading argbind-0.3.9.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from descript-audio-codec->parler_tts==0.2.2) (0.8.0)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (from descript-audio-codec->parler_tts==0.2.2) (2.5.1+cu121)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.10/dist-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.12.1)
# Collecting pyloudnorm (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2)
#   Downloading pyloudnorm-0.1.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (6.4.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.13.1)
# Collecting julius (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2)
#   Downloading julius-0.2.7.tar.gz (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting ffmpy (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2)
#   Downloading ffmpy-0.5.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (7.34.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (13.9.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (3.8.0)
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.10.2.post1)
# Collecting pystoi (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2)
#   Downloading pystoi-0.4.1-py2.py3-none-any.whl.metadata (4.0 kB)
# Collecting torch_stoi (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2)
#   Downloading torch_stoi-0.2.3-py3-none-any.whl.metadata (3.6 kB)
# Collecting flatten-dict (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2)
#   Downloading flatten_dict-0.4.2-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting markdown2 (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2)
#   Downloading markdown2-2.5.2-py3-none-any.whl.metadata (2.1 kB)
# Collecting randomname (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2)
#   Downloading randomname-0.2.1.tar.gz (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (2.17.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->parler_tts==0.2.2) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->parler_tts==0.2.2) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->parler_tts==0.2.2) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->parler_tts==0.2.2) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->parler_tts==0.2.2) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->parler_tts==0.2.2) (1.3.0)
# Requirement already satisfied: docstring-parser in /usr/local/lib/python3.10/dist-packages (from argbind>=0.3.7->descript-audio-codec->parler_tts==0.2.2) (0.16)
# Requirement already satisfied: six<2.0,>=1.12 in /usr/local/lib/python3.10/dist-packages (from flatten-dict->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.17.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (75.1.0)
# Collecting jedi>=0.16 (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->parler_tts==0.2.2) (3.0.2)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.6.0)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.60.0)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.10/dist-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.5.0.post1)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.17.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (2.8.2)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.10/dist-packages (from pyloudnorm->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.0.0)
# Collecting fire (from randomname->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2)
#   Downloading fire-0.7.0.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 8.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (2024.12.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (3.0.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.68.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (3.1.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.1.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.43.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (4.3.6)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.2.13)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (3.5.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire->randomname->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (2.5.0)
# Downloading transformers-4.46.1-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 113.8 MB/s eta 0:00:00
# Downloading descript_audio_codec-1.0.0-py3-none-any.whl (26 kB)
# Downloading tokenizers-0.20.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 85.2 MB/s eta 0:00:00
# Downloading ffmpy-0.5.0-py3-none-any.whl (6.0 kB)
# Downloading flatten_dict-0.4.2-py2.py3-none-any.whl (9.7 kB)
# Downloading markdown2-2.5.2-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 4.4 MB/s eta 0:00:00
# Downloading pyloudnorm-0.1.1-py3-none-any.whl (9.6 kB)
# Downloading pystoi-0.4.1-py2.py3-none-any.whl (8.2 kB)
# Downloading torch_stoi-0.2.3-py3-none-any.whl (8.1 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 74.8 MB/s eta 0:00:00
# Building wheels for collected packages: parler_tts, descript-audiotools, argbind, julius, randomname, fire
#   Building wheel for parler_tts (pyproject.toml) ... done
#   Created wheel for parler_tts: filename=parler_tts-0.2.2-py3-none-any.whl size=81548 sha256=2857bb6faf0473f7e5de53a6451bae4c08c405a61eef1a0dc4e6a7a91a69053b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-sdgfremp/wheels/08/9a/16/7c5e21266463d789fae86d97edb74efc55318f7946736cc645
#   Building wheel for descript-audiotools (setup.py) ... done
#   Created wheel for descript-audiotools: filename=descript_audiotools-0.7.4-py2.py3-none-any.whl size=107918 sha256=3f2376ab9ecd4de540e0d9fc0836cd5f4ce08070a53ee704fe476ebc9c11a122
#   Stored in directory: /tmp/pip-ephem-wheel-cache-sdgfremp/wheels/58/20/2e/8d6d45b762646f67a787680fb04b9b248929d59f46f66d4a0f
#   Building wheel for argbind (setup.py) ... done
#   Created wheel for argbind: filename=argbind-0.3.9-py2.py3-none-any.whl size=11729 sha256=8ac93b7fdf3d5c0b3b3f630cd791e05a3e33fa7012178c7eaf677b60f2b2918d
#   Stored in directory: /root/.cache/pip/wheels/ed/ab/ff/64eb14a776ae6525e1a7d6ad38b73ba020ecc4262d83a7889d
#   Building wheel for julius (setup.py) ... done
#   Created wheel for julius: filename=julius-0.2.7-py3-none-any.whl size=21869 sha256=bd189b2ef61f338f706b0f32786d7a9cf735809538cd24b1b38233a5664c6a7e
#   Stored in directory: /root/.cache/pip/wheels/b9/b2/05/f883527ffcb7f2ead5438a2c23439aa0c881eaa9a4c80256f4
#   Building wheel for randomname (setup.py) ... done
#   Created wheel for randomname: filename=randomname-0.2.1-py3-none-any.whl size=89195 sha256=354f621032769475791c84dd37754f9c9ef00cfe3ef59dcc98a3a7bb36402939
#   Stored in directory: /root/.cache/pip/wheels/10/50/8a/25f3820d26a431ffed1834d72ff2eb349123cf2b44c5a45727
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=37b7ade8fc8e71d5d4e3f807b18b86aaffe72d67ba3ac66d1c6c4cc5734cc633
#   Stored in directory: /root/.cache/pip/wheels/19/39/2f/2d3cadc408a8804103f1c34ddd4b9f6a93497b11fa96fe738e
# Successfully built parler_tts descript-audiotools argbind julius randomname fire
# Installing collected packages: markdown2, jedi, flatten-dict, fire, ffmpy, argbind, randomname, pystoi, pyloudnorm, tokenizers, julius, transformers, torch_stoi, descript-audiotools, descript-audio-codec, parler_tts
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.0
#     Uninstalling tokenizers-0.21.0:
#       Successfully uninstalled tokenizers-0.21.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.47.1
#     Uninstalling transformers-4.47.1:
#       Successfully uninstalled transformers-4.47.1
# Successfully installed argbind-0.3.9 descript-audio-codec-1.0.0 descript-audiotools-0.7.4 ffmpy-0.5.0 fire-0.7.0 flatten-dict-0.4.2 jedi-0.19.2 julius-0.2.7 markdown2-2.5.2 parler_tts-0.2.2 pyloudnorm-0.1.1 pystoi-0.4.1 randomname-0.2.1 tokenizers-0.20.3 torch_stoi-0.2.3 transformers-4.46.1

# %%
import torch
from parler_tts import ParlerTTSForConditionalGeneration

# %%
from transformers import AutoTokenizer
import soundfile as sf

device = "cuda:0" if torch.cuda.is_available() else "cpu"

model = ParlerTTSForConditionalGeneration.from_pretrained("parler-tts/parler-tts-mini-jenny-30H").to(device)
tokenizer = AutoTokenizer.from_pretrained("parler-tts/parler-tts-mini-jenny-30H")

prompt = "Hi! What you did? Are you mad?"
description = "A young female speaks normal, audio is very clear."

input_ids = tokenizer(description, return_tensors="pt").input_ids.to(device)
prompt_input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(device)

generation = model.generate(input_ids=input_ids, prompt_input_ids=prompt_input_ids)
audio = generation.cpu().numpy().squeeze()

print("sample rate: ", model.config.sampling_rate)
sf.write("out.wav", audio, model.config.sampling_rate)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# WARNING:parler_tts.modeling_parler_tts:Config of the text_encoder: <class 'transformers.models.t5.modeling_t5.T5EncoderModel'> is overwritten by shared text_encoder config: T5Config {
#   "_name_or_path": "google/flan-t5-base",
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "classifier_dropout": 0.0,
#   "d_ff": 2048,
#   "d_kv": 64,
#   "d_model": 768,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "gelu_new",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "gated-gelu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 12,
#   "num_heads": 12,
#   "num_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "tie_word_embeddings": false,
#   "transformers_version": "4.46.1",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# WARNING:parler_tts.modeling_parler_tts:Config of the audio_encoder: <class 'parler_tts.dac_wrapper.modeling_dac.DACModel'> is overwritten by shared audio_encoder config: DACConfig {
#   "_name_or_path": "ylacombe/dac_44khZ_8kbps",
#   "architectures": [
#     "DACModel"
#   ],
#   "codebook_size": 1024,
#   "frame_rate": 86,
#   "latent_dim": 1024,
#   "model_bitrate": 8,
#   "model_type": "dac_on_the_hub",
#   "num_codebooks": 9,
#   "sampling_rate": 44100,
#   "torch_dtype": "float32",
#   "transformers_version": "4.46.1"
# }
#
# WARNING:parler_tts.modeling_parler_tts:Config of the decoder: <class 'parler_tts.modeling_parler_tts.ParlerTTSForCausalLM'> is overwritten by shared decoder config: ParlerTTSDecoderConfig {
#   "_name_or_path": "/fsx/yoach/tmp/artefacts/decoder_400M/",
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_cross_attention": true,
#   "architectures": [
#     "StableSpeechForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 1025,
#   "codebook_weights": null,
#   "cross_attention_implementation_strategy": null,
#   "dropout": 0.1,
#   "eos_token_id": 1024,
#   "ffn_dim": 4096,
#   "hidden_size": 1024,
#   "initializer_factor": 0.02,
#   "is_decoder": true,
#   "layerdrop": 0.0,
#   "max_position_embeddings": 4096,
#   "model_type": "parler_tts_decoder",
#   "num_attention_heads": 16,
#   "num_codebooks": 9,
#   "num_cross_attention_key_value_heads": 16,
#   "num_hidden_layers": 24,
#   "num_key_value_heads": 16,
#   "pad_token_id": 1024,
#   "rope_embeddings": false,
#   "rope_theta": 10000.0,
#   "scale_embedding": false,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float32",
#   "transformers_version": "4.46.1",
#   "use_cache": true,
#   "use_fused_lm_heads": false,
#   "vocab_size": 1088
# }
#
# You set `add_prefix_space`. The tokenizer needs to be converted from the slow tokenizers
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# sample rate:  44100

# %%
from IPython.display import Audio, display

display(Audio("out.wav", autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Загружаем Jenny датасет, отделяем небольшую тестовую выборку

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# !pip install datasets

# %%
from datasets import load_dataset
from sklearn.model_selection import train_test_split

dataset = load_dataset("reach-vb/jenny_tts_dataset")
data = dataset["train"] # в датасете только одна часть

# %%
# отделим небольшую тестовую выборку
data = data.train_test_split(test_size=0.003)

# функция для генерации одного аудио
def generate_audio(text, description, model, tokenizer, device):
    input_ids = tokenizer(description, return_tensors="pt").input_ids.to(device)
    prompt_input_ids = tokenizer(text, return_tensors="pt").input_ids.to(device)
    generation = model.generate(input_ids=input_ids, prompt_input_ids=prompt_input_ids)
    audio = generation.cpu().numpy().squeeze()
    return audio

# %%
import os
import soundfile as sf

# Создание директории 'test', если она не существует
if not os.path.exists('test'):
    os.makedirs('test')

# Открытие файла для сохранения текстов
with open("test/transcriptions.txt", "w", encoding="utf-8") as text_file:
    # Обработка каждого примера в тестовой выборке
    for i, example in enumerate(data['test']):
        text = example["transcription"]
        description = "A young female speaks normal, audio is very clear."  # Описание для генерации

        print(f"Predicting the {i:>5}/{len(data['test'])}")

        # Генерация аудио с помощью TTS
        audio = generate_audio(text, description, model, tokenizer, device)

        # Сохранение сгенерированного аудиофайла
        generated_audio_file = f"test/generated_audio_{i}.wav"
        sf.write(generated_audio_file, audio, model.config.sampling_rate)

        # Извлечение и сохранение исходного аудио
        original_audio = example["audio"]["array"]  # Аудиоданные
        original_sr = example["audio"]["sampling_rate"]  # Частота дискретизации
        original_audio_file = f"test/original_audio_{i}.wav"
        sf.write(original_audio_file, original_audio, original_sr)

        # Сохранение текста в файл
        text_file.write(f"generated_audio_{i}.wav: {text}\n")

print("All audio files and transcriptions have been saved.")
# Out:
# Predicting the     0/63
# Predicting the     1/63
# Predicting the     2/63
# Predicting the     3/63
# Predicting the     4/63
# Predicting the     5/63
# Predicting the     6/63
# Predicting the     7/63
# Predicting the     8/63
# Predicting the     9/63
# Predicting the    10/63
# Predicting the    11/63
# Predicting the    12/63
# Predicting the    13/63
# Predicting the    14/63
# Predicting the    15/63
# Predicting the    16/63
# Predicting the    17/63
# Predicting the    18/63
# Predicting the    19/63
# Predicting the    20/63
# Predicting the    21/63
# Predicting the    22/63
# Predicting the    23/63
# Predicting the    24/63
# Predicting the    25/63
# Predicting the    26/63
# Predicting the    27/63
# Predicting the    28/63
# Predicting the    29/63
# Predicting the    30/63
# Predicting the    31/63
# Predicting the    32/63
# Predicting the    33/63
# Predicting the    34/63
# Predicting the    35/63
# Predicting the    36/63
# Predicting the    37/63
# Predicting the    38/63
# Predicting the    39/63
# Predicting the    40/63
# Predicting the    41/63
# Predicting the    42/63
# Predicting the    43/63
# Predicting the    44/63
# Predicting the    45/63
# Predicting the    46/63
# Predicting the    47/63
# Predicting the    48/63
# Predicting the    49/63
# Predicting the    50/63
# Predicting the    51/63
# Predicting the    52/63
# Predicting the    53/63
# Predicting the    54/63
# Predicting the    55/63
# Predicting the    56/63
# Predicting the    57/63
# Predicting the    58/63
# Predicting the    59/63
# Predicting the    60/63
# Predicting the    61/63
# Predicting the    62/63
# All audio files and transcriptions have been saved.

# %% [markdown]
# # Оценка естественности (UTMOS) на Jenny

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# !python3 compute_utmos.py
# Out:
# Downloading: "https://github.com/tarepan/SpeechMOS/zipball/v1.2.0" to /root/.cache/torch/hub/v1.2.0.zip
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# Downloading: "https://github.com/tarepan/SpeechMOS/releases/download/v1.0.0/utmos22_strong_step7459_v1.pt" to /root/.cache/torch/hub/checkpoints/utmos22_strong_step7459_v1.pt
# 100% 392M/392M [00:15<00:00, 26.6MB/s]
# File: test/generated_audio_0.wav
# UTMOS: 4.3870
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_1.wav
# UTMOS: 4.0984
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_2.wav
# UTMOS: 3.5902
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_3.wav
# UTMOS: 4.1858
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_4.wav
# UTMOS: 4.3661
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_5.wav
# UTMOS: 4.3082
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_6.wav
# UTMOS: 4.3166
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_7.wav
# UTMOS: 4.2861
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_8.wav
# UTMOS: 4.0695
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_9.wav
# UTMOS: 4.2357
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_10.wav
# UTMOS: 4.2502
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_11.wav
# UTMOS: 4.2031
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_12.wav
# UTMOS: 4.1592
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_13.wav
# UTMOS: 4.1929
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_14.wav
# UTMOS: 4.3295
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_15.wav
# UTMOS: 4.0540
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_16.wav
# UTMOS: 4.1636
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_17.wav
# UTMOS: 4.0248
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_18.wav
# UTMOS: 4.3100
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_19.wav
# UTMOS: 4.1217
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_20.wav
# UTMOS: 4.2267
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_21.wav
# UTMOS: 4.1403
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_22.wav
# UTMOS: 4.1881
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_23.wav
# UTMOS: 4.0322
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_24.wav
# UTMOS: 4.3517
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_25.wav
# UTMOS: 3.9678
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_26.wav
# UTMOS: 4.1800
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_27.wav
# UTMOS: 3.3760
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_28.wav
# UTMOS: 4.2115
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_29.wav
# UTMOS: 4.3803
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_30.wav
# UTMOS: 4.0194
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_31.wav
# UTMOS: 3.8587
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_32.wav
# UTMOS: 4.2313
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_33.wav
# UTMOS: 4.2558
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_34.wav
# UTMOS: 3.8160
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_35.wav
# UTMOS: 4.4010
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_36.wav
# UTMOS: 4.1986
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_37.wav
# UTMOS: 4.4321
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_38.wav
# UTMOS: 3.7735
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_39.wav
# UTMOS: 4.2644
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_40.wav
# UTMOS: 4.3068
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_41.wav
# UTMOS: 3.6404
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_42.wav
# UTMOS: 3.9847
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_43.wav
# UTMOS: 4.1419
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_44.wav
# UTMOS: 4.2031
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_45.wav
# UTMOS: 4.2495
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_46.wav
# UTMOS: 4.3114
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_47.wav
# UTMOS: 4.3421
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_48.wav
# UTMOS: 4.1626
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_49.wav
# UTMOS: 4.3345
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_50.wav
# UTMOS: 4.1724
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_51.wav
# UTMOS: 3.9966
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_52.wav
# UTMOS: 4.2749
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_53.wav
# UTMOS: 4.3487
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_54.wav
# UTMOS: 4.3114
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_55.wav
# UTMOS: 4.3725
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_56.wav
# UTMOS: 4.3343
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_57.wav
# UTMOS: 4.2848
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_58.wav
# UTMOS: 3.7776
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_59.wav
# UTMOS: 4.3915
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_60.wav
# UTMOS: 4.1320
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_61.wav
# UTMOS: 4.4016
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_62.wav
# UTMOS: 4.1631
# ----------------------------------------------------------------------------------------------------
# Average UTMOS: 4.1682

# %% [markdown]
# Среднее значение - 4.17 / 5, что показывает очень высокую естественность сгенерированных аудио

# %% [markdown]
# # Оценка Разборчивости, точность произношения (WER) на Jenny
#
# Будем использовать Whisper в качестве ASR'а

# %%
# !pip install jiwer
# Out:
# Collecting jiwer
#   Downloading jiwer-3.0.5-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from jiwer) (8.1.7)
# Collecting rapidfuzz<4,>=3 (from jiwer)
#   Downloading rapidfuzz-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading jiwer-3.0.5-py3-none-any.whl (21 kB)
# Downloading rapidfuzz-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 52.2 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-3.0.5 rapidfuzz-3.11.0

# %%
# !python3 compute_wer.py
# Out:
# 2025-01-07 22:45:34.198829: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-07 22:45:34.219947: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-07 22:45:34.226061: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-07 22:45:35.525214: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# config.json: 100% 1.27k/1.27k [00:00<00:00, 5.92MB/s]
# model.safetensors: 100% 3.09G/3.09G [01:12<00:00, 42.3MB/s]
# generation_config.json: 100% 3.90k/3.90k [00:00<00:00, 21.3MB/s]
# tokenizer_config.json: 100% 283k/283k [00:00<00:00, 665kB/s]
# vocab.json: 100% 1.04M/1.04M [00:00<00:00, 2.45MB/s]
# tokenizer.json: 100% 2.48M/2.48M [00:00<00:00, 2.94MB/s]
# merges.txt: 100% 494k/494k [00:00<00:00, 2.28MB/s]
# normalizer.json: 100% 52.7k/52.7k [00:00<00:00, 133MB/s]
# added_tokens.json: 100% 34.6k/34.6k [00:00<00:00, 82.1MB/s]
# special_tokens_map.json: 100% 2.07k/2.07k [00:00<00:00, 12.6MB/s]
# preprocessor_config.json: 100% 340/340 [00:00<00:00, 1.96MB/s]
# Due to a bug fix in https://github.com/huggingface/transformers/pull/28687 transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English.This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`.
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.43.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# File: test/generated_audio_0.wav
# Original: the main actors are dax shepard and michael pena.
# Predicted:  the main actors are dax shepard and michael pena,
# WER: 0.1111
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_1.wav
# Original: let me get you a song to hear.
# Predicted:  let me get you a song to hear.
# WER: 0.0000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_2.wav
# Original: yes.
# Predicted:  yes.
# WER: 0.0000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_3.wav
# Original: the only evidence to the contrary was the mute protest in your own bones, the instinctive feeling that the conditions you lived in were intolerable and that at some other time they must have been different.
# Predicted:  the only evidence to the contrary was the mute protest in your own bones, the instinctive feeling that the conditions you lived in were intolerable and that at some other time they must have been different.
# WER: 0.0000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_4.wav
# Original: from your home, to your diet and how you shop: simple changes you can make to live more sustainably
# Predicted:  from your home to your diet and how you shop, simple changes you can make to live more sustainably.
# WER: 0.1579
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_5.wav
# Original: estimates vary, mainly over the question of which denominations to classify as protestant.
# Predicted:  exodus vary, mainly over the question of which denominations to classify as protestant.
# WER: 0.0769
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_6.wav
# Original: i took a sailing holiday – on one of norfolk’s historic wherries
# Predicted:  i took a sailing holiday on one of norfolk's historic wherries.
# WER: 0.2500
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_7.wav
# Original: just think, he's given you her piano.
# Predicted:  just think, he's given you her piano.
# WER: 0.0000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_8.wav
# Original: well, not at first, but it was very intricate work and they said even though they lost their sight, it was all worth it.
# Predicted:  well, not at first, but it was very intricate work, and they said even though they lost their sight, it was all worth it.
# WER: 0.0417
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_9.wav
# Original: sounds good, that's possible.
# Predicted:  sounds good. that's possible.
# WER: 0.2500
# ----------------------------------------------------------------------------------------------------
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# File: test/generated_audio_10.wav
# Original: the address.
# Predicted:  the address.
# WER: 0.0000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_11.wav
# Original: the deception that is ‘levelling up’
# Predicted:  the deception, that is, is a dig effenam.
# WER: 0.8333
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_12.wav
# Original: 'may we, mother?'
# Predicted:  may we, mother?
# WER: 0.6667
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_13.wav
# Original: you can run if you want but you can't hide
# Predicted:  you can run if you want, but you can't hide.
# WER: 0.2000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_14.wav
# Original: still i got to know if this is real or just a dream
# Predicted:  still, i got to know if this is real or just a dream.
# WER: 0.1538
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_15.wav
# Original: 'it's a church, or at least it used to be.
# Predicted:  it's a church, or at least it used to be.
# WER: 0.1000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_16.wav
# Original: victorian workplace watchdog alleges hotel quarantine system put staff ‘at risk of illness or death’
# Predicted:  roryan mouiliel, watchdog, alleges hotel quarantine system puts staff probably at risk of illness or death.
# WER: 0.4667
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_17.wav
# Original: no wait, you don't get to leave!
# Predicted:  no wait, you don't get to leave.
# WER: 0.1429
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_18.wav
# Original: this christmas i am all alone
# Predicted:  this christmas, i am all alone.
# WER: 0.3333
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_19.wav
# Original: jailed saudi aid worker’s sister hits out at newcastle takeover
# Predicted:  jailed tenementian aid worker, sister hits out at newcastle-de-acover.
# WER: 0.4000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_20.wav
# Original: weeks have passed, but no trace of her has been discovered, and we relinquish all hope, tie a black ribbon to her basket, set aside her dish, and weep for her as one lost to us forever.
# Predicted:  weeks have passed but no trace of her has been discovered and we relinquish all hope tie a black ribbon to her basket set aside her dish and weep for her as one lost to us forever
# WER: 0.1622
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_21.wav
# Original: she had a decided mouth, a comical nose, and sharp, gray eyes, which appeared to see everything, and were by turns fierce, funny, or thoughtful.
# Predicted:  she had a decided mouth, a comical nose, and sharp grey eyes, which appeared to see everything, and were by turns fierce, funny or thoughtful.
# WER: 0.1200
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_22.wav
# Original: day and night the telescreens bruised your ears with statistics proving that people today had more food, more clothes, better houses, better recreations -- that they lived longer, worked shorter hours, were bigger, healthier, stronger, happier, more intelligent, better educated, than the people of fifty years ago.
# Predicted:  day and night the telescreens bruised your ears with statistics proving that people today had more food, more clothes, better houses, better recreations, that they lived longer, worked shorter hours, were bigger, healthier.
# WER: 0.3404
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_23.wav
# Original: but the mindless tenderness that he had felt under the hazel tree, while the thrush was singing, had not quite come back.
# Predicted:  but the mindless tenderness that he had felt under the hazel tree while the thrush was singing.
# WER: 0.3182
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_24.wav
# Original: you sit on the bank and pass the time away
# Predicted:  you sit on the bank and pass the time away.
# WER: 0.1000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_25.wav
# Original: other biotechnology tools include dna microarrays, expression vectors, synthetic genomics, and crispr gene editing.
# Predicted:  other biogene tools include micro-arrays expression vectors, synthetic beaters and cryo-segurite gene editing.
# WER: 0.3571
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_26.wav
# Original: tfl granted injunction against insulate britain protesters after arrests
# Predicted:  the granted injunction against insulate britain protesters
# WER: 0.3333
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_27.wav
# Original: how can i help you?
# Predicted:  how can i help you?
# WER: 0.0000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_28.wav
# Original: the eastern catholic churches, which developed different disciplines and practices, are governed by the code of canons of the eastern churches.
# Predicted:  eastern catholic churches, which develop different disciplines and practices, are governed by the code of canons of the eastern churches.
# WER: 0.0952
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_29.wav
# Original: those are the two options. which one do you want?
# Predicted:  those are the two options. which one do you want?
# WER: 0.0000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_30.wav
# Original: o'brien took the decanter by the neck and filled up the glasses with a dark-red liquid.
# Predicted:  o'brien took the decanter by the neck and filled up the glasses with the dark red liquid.
# WER: 0.1875
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_31.wav
# Original: 'oh, thank you!
# Predicted:  oh, thank you.
# WER: 0.6667
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_32.wav
# Original: he used to say it to me when i was a little girl.
# Predicted:  he used to say it to me when i was a little girl.
# WER: 0.0000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_33.wav
# Original: drivers clash with insulate britain activists blocking three london roads
# Predicted:  dravers clash with instantly hate britain, blocking three london roads.
# WER: 0.5000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_34.wav
# Original: ok. what type of pizza?
# Predicted:  oh, what type of pizza?
# WER: 0.2000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_35.wav
# Original: he was also a major creep i found out later, and terrible with girls as soon as he opened his mouth.
# Predicted:  he was also a major creep. i found out later and terrible with girls as soon as he opened his mouth.
# WER: 0.0952
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_36.wav
# Original: it was easier to try for your sakes than for my own.
# Predicted:  it was easier to try for your sakes and for my own.
# WER: 0.0833
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_37.wav
# Original: for speciation to occur, there has to be reproductive isolation.
# Predicted:  for speciation to occur, there has to be reproductive isolation.
# WER: 0.0000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_38.wav
# Original: didn't you listen to the story?
# Predicted:  didn't you listen to the story?
# WER: 0.0000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_39.wav
# Original: ‘creativity is about thinking differently’: an advertising trailblazer on the secrets of staying inspired
# Predicted:  retreativity is about thinking differently. an advertising trailblazer on the secrets of staying inspired.
# WER: 0.2143
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_40.wav
# Original: it was excellent drill for their memories, a harmless amusement, and employed many hours which otherwise would have been idle, lonely, or spent in less profitable society.
# Predicted:  it was excellent will for their memories, a harmless amusement, and employed many hours which otherwise would have been idle, lonely or spent in less profitable society.
# WER: 0.0741
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_41.wav
# Original: coke.
# Predicted:  coke.
# WER: 0.0000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_42.wav
# Original: 'what time?'.
# Predicted:  what time?
# WER: 1.0000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_43.wav
# Original: who is their biggest rival?
# Predicted:  who is their biggest rival?
# WER: 0.0000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_44.wav
# Original: oh, no more waitin', let's be spontaneous
# Predicted:  oh, no more. wait and let's be spontaneous.
# WER: 0.5714
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_45.wav
# Original: sometimes there's a censorship version.
# Predicted:  sometimes there is a censorship version.
# WER: 0.4000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_46.wav
# Original: tax law involves regulations that concern value added tax, corporate tax, and income tax.
# Predicted:  tax law involves regulations that concern value-added tax, corporate tax and income tax.
# WER: 0.2143
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_47.wav
# Original: the inscription on the title-page ran:
# Predicted:  the inscription on the title page ran
# WER: 0.5000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_48.wav
# Original: is your glass half full or is it half empty
# Predicted:  is your glass half full or is it half empty?
# WER: 0.1000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_49.wav
# Original: with a rather absent-minded air o'brien pushed them towards the others, took one himself, then stood up and began to pace slowly to and fro, as though he could think better standing.
# Predicted:  with a rather absent-minded air, o'brien pushed them towards the others, took one himself.
# WER: 0.6250
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_50.wav
# Original: how about your return flight?
# Predicted:  how about your return flights?
# WER: 0.2000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_51.wav
# Original: is one of those strangers you?
# Predicted:  is one of those strangers you?
# WER: 0.0000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_52.wav
# Original: it's been really interesting to learn about the first world war from a new perspective.
# Predicted:  it's been really interesting to learn about the first world war from a new perspective.
# WER: 0.0000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_53.wav
# Original: so that question i'm now going to ask to all of you.
# Predicted:  so that question i'm now going to ask to all of you.
# WER: 0.0000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_54.wav
# Original: as i was headed out towards the door
# Predicted:  as i was headed out towards the door.
# WER: 0.1250
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_55.wav
# Original: however, the only way i can see him changing is that he keeps becoming more and more of a weak personality who continues to leech off of his friends.
# Predicted:  however, the only way i can see him changing is that he keeps becoming more and more of a weak personality who continues to leech off of his friends.
# WER: 0.0000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_56.wav
# Original: we may as well go back to the place in the wood.
# Predicted:  we may as well go back to the place in the wood.
# WER: 0.0000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_57.wav
# Original: okay. i appreciate your help.
# Predicted:  poor casey. i appreciate your help.
# WER: 0.4000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_58.wav
# Original: see you later.
# Predicted:  and see you later.
# WER: 0.3333
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_59.wav
# Original: from annette to shang-chi: eight new films to watch as australian cinemas reopen
# Predicted:  from annette to shan qi, eight new films to watch as australian cinemas reopen.
# WER: 0.2308
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_60.wav
# Original: indian philosophical traditions share various key concepts and ideas, which are defined in different ways and accepted or rejected by the different traditions.
# Predicted:  indian philosophic logicians share various key concepts and ideas, which are defined in different ways and accepted or rejected by the different traditions.
# WER: 0.0870
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_61.wav
# Original: here's one more for an idea.
# Predicted:  here's one more for an idea.
# WER: 0.0000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_62.wav
# Original: otherwise you won't survive.
# Predicted:  otherwise, you won't survive.
# WER: 0.2500
# ----------------------------------------------------------------------------------------------------
# Average WER: 0.2074

# %% [markdown]
# Средний WER довольно маленький, в основном ошибки происходят из-за различий в пунктуации

# %% [markdown]
# # Оценка сходства голосов (SECS) на Jenny

# %%
# !python3 compute_secs.py
# Out:
# 2025-01-07 23:01:04.819192: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-07 23:01:04.851974: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-07 23:01:04.861895: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-07 23:01:06.713816: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:5849: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# File: 0
# Original: test/original_audio_0.wav
# Generated: test/generated_audio_0.wav
# SECS: 0.9538
# --------------------------------------------------
# File: 1
# Original: test/original_audio_1.wav
# Generated: test/generated_audio_1.wav
# SECS: 0.9149
# --------------------------------------------------
# File: 2
# Original: test/original_audio_2.wav
# Generated: test/generated_audio_2.wav
# SECS: 0.8098
# --------------------------------------------------
# File: 3
# Original: test/original_audio_3.wav
# Generated: test/generated_audio_3.wav
# SECS: 0.9802
# --------------------------------------------------
# File: 4
# Original: test/original_audio_4.wav
# Generated: test/generated_audio_4.wav
# SECS: 0.9810
# --------------------------------------------------
# File: 5
# Original: test/original_audio_5.wav
# Generated: test/generated_audio_5.wav
# SECS: 0.9691
# --------------------------------------------------
# File: 6
# Original: test/original_audio_6.wav
# Generated: test/generated_audio_6.wav
# SECS: 0.9822
# --------------------------------------------------
# File: 7
# Original: test/original_audio_7.wav
# Generated: test/generated_audio_7.wav
# SECS: 0.9512
# --------------------------------------------------
# File: 8
# Original: test/original_audio_8.wav
# Generated: test/generated_audio_8.wav
# SECS: 0.9760
# --------------------------------------------------
# File: 9
# Original: test/original_audio_9.wav
# Generated: test/generated_audio_9.wav
# SECS: 0.9258
# --------------------------------------------------
# File: 10
# Original: test/original_audio_10.wav
# Generated: test/generated_audio_10.wav
# SECS: 0.7487
# --------------------------------------------------
# File: 11
# Original: test/original_audio_11.wav
# Generated: test/generated_audio_11.wav
# SECS: 0.9246
# --------------------------------------------------
# File: 12
# Original: test/original_audio_12.wav
# Generated: test/generated_audio_12.wav
# SECS: 0.9129
# --------------------------------------------------
# File: 13
# Original: test/original_audio_13.wav
# Generated: test/generated_audio_13.wav
# SECS: 0.9634
# --------------------------------------------------
# File: 14
# Original: test/original_audio_14.wav
# Generated: test/generated_audio_14.wav
# SECS: 0.9474
# --------------------------------------------------
# File: 15
# Original: test/original_audio_15.wav
# Generated: test/generated_audio_15.wav
# SECS: 0.9398
# --------------------------------------------------
# File: 16
# Original: test/original_audio_16.wav
# Generated: test/generated_audio_16.wav
# SECS: 0.9814
# --------------------------------------------------
# File: 17
# Original: test/original_audio_17.wav
# Generated: test/generated_audio_17.wav
# SECS: 0.9380
# --------------------------------------------------
# File: 18
# Original: test/original_audio_18.wav
# Generated: test/generated_audio_18.wav
# SECS: 0.9550
# --------------------------------------------------
# File: 19
# Original: test/original_audio_19.wav
# Generated: test/generated_audio_19.wav
# SECS: 0.9472
# --------------------------------------------------
# File: 20
# Original: test/original_audio_20.wav
# Generated: test/generated_audio_20.wav
# SECS: 0.9706
# --------------------------------------------------
# File: 21
# Original: test/original_audio_21.wav
# Generated: test/generated_audio_21.wav
# SECS: 0.9675
# --------------------------------------------------
# File: 22
# Original: test/original_audio_22.wav
# Generated: test/generated_audio_22.wav
# SECS: 0.9780
# --------------------------------------------------
# File: 23
# Original: test/original_audio_23.wav
# Generated: test/generated_audio_23.wav
# SECS: 0.9531
# --------------------------------------------------
# File: 24
# Original: test/original_audio_24.wav
# Generated: test/generated_audio_24.wav
# SECS: 0.9356
# --------------------------------------------------
# File: 25
# Original: test/original_audio_25.wav
# Generated: test/generated_audio_25.wav
# SECS: 0.9791
# --------------------------------------------------
# File: 26
# Original: test/original_audio_26.wav
# Generated: test/generated_audio_26.wav
# SECS: 0.9804
# --------------------------------------------------
# File: 27
# Original: test/original_audio_27.wav
# Generated: test/generated_audio_27.wav
# SECS: 0.9468
# --------------------------------------------------
# File: 28
# Original: test/original_audio_28.wav
# Generated: test/generated_audio_28.wav
# SECS: 0.9749
# --------------------------------------------------
# File: 29
# Original: test/original_audio_29.wav
# Generated: test/generated_audio_29.wav
# SECS: 0.9202
# --------------------------------------------------
# File: 30
# Original: test/original_audio_30.wav
# Generated: test/generated_audio_30.wav
# SECS: 0.9627
# --------------------------------------------------
# File: 31
# Original: test/original_audio_31.wav
# Generated: test/generated_audio_31.wav
# SECS: 0.7894
# --------------------------------------------------
# File: 32
# Original: test/original_audio_32.wav
# Generated: test/generated_audio_32.wav
# SECS: 0.9649
# --------------------------------------------------
# File: 33
# Original: test/original_audio_33.wav
# Generated: test/generated_audio_33.wav
# SECS: 0.9823
# --------------------------------------------------
# File: 34
# Original: test/original_audio_34.wav
# Generated: test/generated_audio_34.wav
# SECS: 0.9571
# --------------------------------------------------
# File: 35
# Original: test/original_audio_35.wav
# Generated: test/generated_audio_35.wav
# SECS: 0.9825
# --------------------------------------------------
# File: 36
# Original: test/original_audio_36.wav
# Generated: test/generated_audio_36.wav
# SECS: 0.9764
# --------------------------------------------------
# File: 37
# Original: test/original_audio_37.wav
# Generated: test/generated_audio_37.wav
# SECS: 0.9713
# --------------------------------------------------
# File: 38
# Original: test/original_audio_38.wav
# Generated: test/generated_audio_38.wav
# SECS: 0.9247
# --------------------------------------------------
# File: 39
# Original: test/original_audio_39.wav
# Generated: test/generated_audio_39.wav
# SECS: 0.9809
# --------------------------------------------------
# File: 40
# Original: test/original_audio_40.wav
# Generated: test/generated_audio_40.wav
# SECS: 0.9818
# --------------------------------------------------
# File: 41
# Original: test/original_audio_41.wav
# Generated: test/generated_audio_41.wav
# SECS: 0.6502
# --------------------------------------------------
# File: 42
# Original: test/original_audio_42.wav
# Generated: test/generated_audio_42.wav
# SECS: 0.8491
# --------------------------------------------------
# File: 43
# Original: test/original_audio_43.wav
# Generated: test/generated_audio_43.wav
# SECS: 0.8610
# --------------------------------------------------
# File: 44
# Original: test/original_audio_44.wav
# Generated: test/generated_audio_44.wav
# SECS: 0.9519
# --------------------------------------------------
# File: 45
# Original: test/original_audio_45.wav
# Generated: test/generated_audio_45.wav
# SECS: 0.9267
# --------------------------------------------------
# File: 46
# Original: test/original_audio_46.wav
# Generated: test/generated_audio_46.wav
# SECS: 0.9561
# --------------------------------------------------
# File: 47
# Original: test/original_audio_47.wav
# Generated: test/generated_audio_47.wav
# SECS: 0.9724
# --------------------------------------------------
# File: 48
# Original: test/original_audio_48.wav
# Generated: test/generated_audio_48.wav
# SECS: 0.9376
# --------------------------------------------------
# File: 49
# Original: test/original_audio_49.wav
# Generated: test/generated_audio_49.wav
# SECS: 0.9730
# --------------------------------------------------
# File: 50
# Original: test/original_audio_50.wav
# Generated: test/generated_audio_50.wav
# SECS: 0.9532
# --------------------------------------------------
# File: 51
# Original: test/original_audio_51.wav
# Generated: test/generated_audio_51.wav
# SECS: 0.9678
# --------------------------------------------------
# File: 52
# Original: test/original_audio_52.wav
# Generated: test/generated_audio_52.wav
# SECS: 0.9622
# --------------------------------------------------
# File: 53
# Original: test/original_audio_53.wav
# Generated: test/generated_audio_53.wav
# SECS: 0.9197
# --------------------------------------------------
# File: 54
# Original: test/original_audio_54.wav
# Generated: test/generated_audio_54.wav
# SECS: 0.9029
# --------------------------------------------------
# File: 55
# Original: test/original_audio_55.wav
# Generated: test/generated_audio_55.wav
# SECS: 0.9641
# --------------------------------------------------
# File: 56
# Original: test/original_audio_56.wav
# Generated: test/generated_audio_56.wav
# SECS: 0.9610
# --------------------------------------------------
# File: 57
# Original: test/original_audio_57.wav
# Generated: test/generated_audio_57.wav
# SECS: 0.8016
# --------------------------------------------------
# File: 58
# Original: test/original_audio_58.wav
# Generated: test/generated_audio_58.wav
# SECS: 0.9130
# --------------------------------------------------
# File: 59
# Original: test/original_audio_59.wav
# Generated: test/generated_audio_59.wav
# SECS: 0.9779
# --------------------------------------------------
# File: 60
# Original: test/original_audio_60.wav
# Generated: test/generated_audio_60.wav
# SECS: 0.9737
# --------------------------------------------------
# File: 61
# Original: test/original_audio_61.wav
# Generated: test/generated_audio_61.wav
# SECS: 0.9303
# --------------------------------------------------
# File: 62
# Original: test/original_audio_62.wav
# Generated: test/generated_audio_62.wav
# SECS: 0.8552
# --------------------------------------------------
# Average SECS: 0.9356

# %% [markdown]
# довольно высокое SECS, для примера у Tacotroon в [исходной статье](https://arxiv.org/abs/2104.05557) около 0.75 на 55 аудио из VCTK датасета

# %% [markdown]
# # Распаковка датасета Libri Speech test clean

# %%
import os
import tarfile
import shutil
import soundfile as sf
import numpy as np
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModel

# Скачивание и распаковка датасета
def download_and_extract_librispeech():
    dataset_url = "https://www.openslr.org/resources/12/test-clean.tar.gz"
    dataset_path = "test-clean.tar.gz"
    extract_path = "LibriSpeech"

    # Скачивание датасета (если еще не скачан)
    if not os.path.exists(dataset_path):
        os.system(f"wget {dataset_url} -O {dataset_path}")

    # Распаковка датасета (если еще не распакован)
    if not os.path.exists(extract_path):
        with tarfile.open(dataset_path, "r:gz") as tar:
            tar.extractall(path=".")

# Загрузка данных из LibriSpeech
def load_librispeech_data():
    data = []
    base_path = "LibriSpeech/test-clean"
    for root, _, files in os.walk(base_path):
        for file in files:
            if file.endswith(".txt"):
                with open(os.path.join(root, file), "r") as f:
                    for line in f:
                        parts = line.strip().split(" ", 1)
                        if len(parts) == 2:
                            audio_id, text = parts
                            audio_path = os.path.join(root, f"{audio_id}.flac")
                            if os.path.exists(audio_path):
                                data.append({"audio": audio_path, "text": text})
    return data

# Отделение 60 примеров
def select_samples(data, num_samples=60):
    np.random.seed(42)  # Для воспроизводимости
    indices = np.random.choice(len(data), num_samples, replace=False)
    return [data[i] for i in indices]

# Функция для генерации аудио
def generate_audio(text, description, model, tokenizer, device):
    input_ids = tokenizer(description, return_tensors="pt").input_ids.to(device)
    prompt_input_ids = tokenizer(text, return_tensors="pt").input_ids.to(device)
    generation = model.generate(input_ids=input_ids, prompt_input_ids=prompt_input_ids)
    audio = generation.cpu().numpy().squeeze()
    return audio

# %% [markdown]
# Распаковываем 60 записей в директорию ./test

# %%
test_dir = "test"

# Скачивание и распаковка датасета
download_and_extract_librispeech()

# Загрузка данных
librispeech_data = load_librispeech_data()

# Отделение 63 примеров
selected_data = select_samples(librispeech_data, num_samples=63)

# Очистка и создание директории 'test'
if os.path.exists(test_dir):
    shutil.rmtree(test_dir)
os.makedirs(test_dir)

# %%
with open(os.path.join(test_dir, "transcriptions.txt"), "w", encoding="utf-8") as text_file:
    # Обработка каждого примера в тестовой выборке
    for i, example in enumerate(selected_data):
        text = example["text"]
        description = "A young female speaks normal, audio is very clear."  # Описание для генерации

        print(f"Predicting the {i:>5}/{len(selected_data)}")

        # Генерация аудио с помощью TTS
        audio = generate_audio(text, description, model, tokenizer, "cuda" if torch.cuda.is_available() else "cpu")

        # Сохранение сгенерированного аудиофайла
        generated_audio_file = os.path.join(test_dir, f"generated_audio_{i}.wav")
        sf.write(generated_audio_file, audio, model.config.sampling_rate)

        # Извлечение и сохранение исходного аудио
        original_audio, original_sr = sf.read(example["audio"])
        original_audio_file = os.path.join(test_dir, f"original_audio_{i}.wav")
        sf.write(original_audio_file, original_audio, original_sr)

        # Сохранение текста в файл
        text_file.write(f"generated_audio_{i}.wav: {text}\n")
        text_file.write(f"original_audio_{i}.wav: {text}\n")

print("All audio files and transcriptions have been saved.")
# Out:
# Predicting the     0/63
# Predicting the     1/63
# Predicting the     2/63
# Predicting the     3/63
# Predicting the     4/63
# Predicting the     5/63
# Predicting the     6/63
# Predicting the     7/63
# Predicting the     8/63
# Predicting the     9/63
# Predicting the    10/63
# Predicting the    11/63
# Predicting the    12/63
# Predicting the    13/63
# Predicting the    14/63
# Predicting the    15/63
# Predicting the    16/63
# Predicting the    17/63
# Predicting the    18/63
# Predicting the    19/63
# Predicting the    20/63
# Predicting the    21/63
# Predicting the    22/63
# Predicting the    23/63
# Predicting the    24/63
# Predicting the    25/63
# Predicting the    26/63
# Predicting the    27/63
# Predicting the    28/63
# Predicting the    29/63
# Predicting the    30/63
# Predicting the    31/63
# Predicting the    32/63
# Predicting the    33/63
# Predicting the    34/63
# Predicting the    35/63
# Predicting the    36/63
# Predicting the    37/63
# Predicting the    38/63
# Predicting the    39/63
# Predicting the    40/63
# Predicting the    41/63
# Predicting the    42/63
# Predicting the    43/63
# Predicting the    44/63
# Predicting the    45/63
# Predicting the    46/63
# Predicting the    47/63
# Predicting the    48/63
# Predicting the    49/63
# Predicting the    50/63
# Predicting the    51/63
# Predicting the    52/63
# Predicting the    53/63
# Predicting the    54/63
# Predicting the    55/63
# Predicting the    56/63
# Predicting the    57/63
# Predicting the    58/63
# Predicting the    59/63
# Predicting the    60/63
# Predicting the    61/63
# Predicting the    62/63
# All audio files and transcriptions have been saved.

# %% [markdown]
# # Оценка естественности (UTMOS) на Libri Speech test clean

# %%
# !python3 compute_utmos.py
# Out:
# Using cache found in /root/.cache/torch/hub/tarepan_SpeechMOS_v1.2.0
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# File: test/generated_audio_0.wav
# UTMOS: 4.1716
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_1.wav
# UTMOS: 3.9030
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_2.wav
# UTMOS: 4.1809
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_3.wav
# UTMOS: 4.3384
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_4.wav
# UTMOS: 4.1807
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_5.wav
# UTMOS: 4.3696
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_6.wav
# UTMOS: 4.2779
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_7.wav
# UTMOS: 4.0213
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_8.wav
# UTMOS: 4.0518
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_9.wav
# UTMOS: 4.1228
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_10.wav
# UTMOS: 4.3479
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_11.wav
# UTMOS: 4.1795
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_12.wav
# UTMOS: 3.8882
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_13.wav
# UTMOS: 4.1075
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_14.wav
# UTMOS: 4.3010
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_15.wav
# UTMOS: 3.9480
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_16.wav
# UTMOS: 4.3742
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_17.wav
# UTMOS: 3.9323
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_18.wav
# UTMOS: 3.4650
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_19.wav
# UTMOS: 4.4342
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_20.wav
# UTMOS: 4.3132
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_21.wav
# UTMOS: 4.1817
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_22.wav
# UTMOS: 3.8921
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_23.wav
# UTMOS: 4.2413
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_24.wav
# UTMOS: 4.0686
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_25.wav
# UTMOS: 2.5543
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_26.wav
# UTMOS: 3.9716
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_27.wav
# UTMOS: 3.9100
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_28.wav
# UTMOS: 3.9674
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_29.wav
# UTMOS: 3.8811
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_30.wav
# UTMOS: 3.8777
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_31.wav
# UTMOS: 4.3506
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_32.wav
# UTMOS: 4.3896
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_33.wav
# UTMOS: 3.9062
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_34.wav
# UTMOS: 3.8558
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_35.wav
# UTMOS: 4.2098
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_36.wav
# UTMOS: 4.3536
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_37.wav
# UTMOS: 4.1018
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_38.wav
# UTMOS: 4.2104
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_39.wav
# UTMOS: 4.1351
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_40.wav
# UTMOS: 4.2301
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_41.wav
# UTMOS: 4.0931
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_42.wav
# UTMOS: 4.2863
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_43.wav
# UTMOS: 4.2568
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_44.wav
# UTMOS: 4.2227
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_45.wav
# UTMOS: 3.9909
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_46.wav
# UTMOS: 4.2404
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_47.wav
# UTMOS: 4.0399
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_48.wav
# UTMOS: 4.3127
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_49.wav
# UTMOS: 3.9580
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_50.wav
# UTMOS: 4.3179
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_51.wav
# UTMOS: 4.2121
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_52.wav
# UTMOS: 3.6116
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_53.wav
# UTMOS: 4.0580
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_54.wav
# UTMOS: 4.2772
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_55.wav
# UTMOS: 4.2505
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_56.wav
# UTMOS: 3.9750
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_57.wav
# UTMOS: 4.0621
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_58.wav
# UTMOS: 4.2649
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_59.wav
# UTMOS: 4.3092
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_60.wav
# UTMOS: 4.1347
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_61.wav
# UTMOS: 4.1125
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_62.wav
# UTMOS: 4.3427
# ----------------------------------------------------------------------------------------------------
# Average UTMOS: 4.1036

# %% [markdown]
# # Оценка Разборчивости, точность произношения (WER) на Libri Speech test clean

# %%
# !python3 compute_wer.py
# Out:
# 2025-01-07 23:33:31.076237: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-07 23:33:31.098143: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-07 23:33:31.104291: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-07 23:33:32.504166: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Due to a bug fix in https://github.com/huggingface/transformers/pull/28687 transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English.This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`.
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.43.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# File: test/generated_audio_0.wav
# Original: the more she is engaged in her proper duties the less leisure will she have for it even as an accomplishment and a recreation
# Predicted:  the more she is engaged in her proper duties the less, the more will she have for us, even as an accomplishment and a retribution.
# WER: 0.2083
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_1.wav
# Original: thus if i recognize a thing the occasion of its previous existence in virtue of which i recognize it forms part of my experience by definition recognition will be one of the marks by which my experience is singled out from the rest of the world
# Predicted:  this is i re, nae malise ae thing the oare, as it's to vee's existence, in virtue of which i re nae lies, at forens my as ae thing the oaf is surents, by definition reck not in vastation, will be one of the marks by which my ex pre exprients, is
# WER: 0.8261
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_2.wav
# Original: and so life and death have dispersed the circle of violent radicals and dissenters into which twenty years ago the little quiet resolute clergyman's daughter was received and by whom she was truly loved and honoured
# Predicted:  and so life and death have dispersed the circle of violent radicals and dissenters into which twenty years ago the little choir gisennos, quebissory genes, georgiades, cadmains, et tuis received, and be whom she was truly loved.
# WER: 0.3611
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_3.wav
# Original: it might have seemed that a trout of this size was a fairly substantial meal
# Predicted:  it might have seemed that a trout of this size was a fairly substantial meal.
# WER: 0.0667
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_4.wav
# Original: i will briefly describe them to you and you shall read the account of them at your leisure in the sacred registers
# Predicted:  i will bribe like day, then to you we shall write the account of the amateur largerth, in the sacred re-usure in the sacred rears.
# WER: 0.6818
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_5.wav
# Original: january and february of eighteen thirty seven had passed away and still there was no reply from southey
# Predicted:  jiuri, of 1837 han dixing, had passed away and still the reply, from sade.
# WER: 0.6111
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_6.wav
# Original: every one could observe his agitation and prostration a prostration which was indeed the more remarkable since people were not accustomed to see him with his arms hanging listlessly by his side his head bewildered and his eyes with all their bright intelligence bedimmed
# Predicted:  one could observe agitation and prostration in vituation. it is an more remarkable
# WER: 0.8182
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_7.wav
# Original: farewell madam
# Predicted:  to you well, my dema.
# WER: 2.5000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_8.wav
# Original: onward said a distant voice
# Predicted:  onward, said a distant voice.
# WER: 0.4000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_9.wav
# Original: the south she had not thought of seriously and yet knowing of its delightful hospitality and mild climate she was not averse to charleston or new orleans
# Predicted:  but so she had not of seriously and yet knowing of its delighty and mild clarity and mild climate she was not averse to charleston or new orleans
# WER: 0.2593
# ----------------------------------------------------------------------------------------------------
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# File: test/generated_audio_10.wav
# Original: john taylor who had supported her through college was interested in cotton
# Predicted:  john tuller who had, reported through, kelsiech was interested in cotton.
# WER: 0.5833
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_11.wav
# Original: when they were outside unc simply latched the door and started up the path
# Predicted:  when they were outside on simpli, latched the door and started up the pies.
# WER: 0.2143
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_12.wav
# Original: come come i am getting really tired of your absence
# Predicted:  communicate the courage of your absence.
# WER: 0.8000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_13.wav
# Original: a terrible thought flashed into my mind
# Predicted:  a terrible thought into my mind.
# WER: 0.2857
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_14.wav
# Original: that's the way with you that's the road you'd all like to go headlongs to ruin
# Predicted:  that's the way with you. all likes to go, headlongs to ream.
# WER: 0.5000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_15.wav
# Original: from these again sprang barricaded and fortified dwellings camps and scouting parties finally culminating in roving guerrilla bands half partisan half predatory
# Predicted:  from these, again, spurn aim, barriers to fight gelling's curbs, and southing parties finally co-mediating roving guerrilla bands. health partisan, health partisans are we.
# WER: 0.8636
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_16.wav
# Original: it was one of the masterly and charming stories of dumas the elder
# Predicted:  it was one of the masterly and charming stories of jumaris the elder.
# WER: 0.1538
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_17.wav
# Original: i refer to the thermometer it indicates the figure is obliterated
# Predicted:  i refer to the layers indicates the figure is obliterated.
# WER: 0.2727
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_18.wav
# Original: envy hatred malice and uncharitableness are never so essentially detestable to my mind as when they are animated by a sense of propriety and work under the surface but for my interest in naomi and my other interest in the little love looks which i now and then surprised passing between her and ambrose i should never have sat through that supper
# Predicted:  in the evening, etched models are never so essentially detestable to my mind of. i never work under the seeds of practice that i work under. it's so essentially detestable.
# WER: 0.8065
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_19.wav
# Original: she was so strange and human a creature
# Predicted:  she was so strange and tame and a creature.
# WER: 0.3750
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_20.wav
# Original: but even the unsuccessful dramatist has his moments
# Predicted:  the tzimdi onsos, cessful dramanations, his moments.
# WER: 0.8750
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_21.wav
# Original: a large open fireplace with rusty dogs in it and a bare boarded floor at the far end fleeces of wool stacked up in the middle of the floor some empty corn bags
# Predicted:  a large open fireplace with rusty dogs in it and a bare barred flea fixations of wool stacked it up in the middle of the floor some empty corn bags.
# WER: 0.2727
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_22.wav
# Original: smuggling the house cleaning paraphernalia into the cellar window unobserved that afternoon proved no easy task for cynthia had added a whisk broom and dust pan to the outfit
# Predicted:  sámaglinn dhe haus clérinín pérri in tói dhe sallar wain dhó. ám sérfa dhe dháis dhéin ríosín dhe pérra sámb, mannín tóisí, tóis tói frasín sía, háid anáidhú, é mú sté.
# WER: 1.0690
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_23.wav
# Original: munny i tould ike to do into de barn to tommy to see de whittawd
# Predicted:  many people have been told that the children are not allowed to speak english.
# WER: 0.9333
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_24.wav
# Original: from rubbing shoulders with scientists in our little universe by the botanical gardens the boy had come to know a thing or two
# Predicted:  roping shutters in our little universe by the bunky and averse by the botanical gardens, the boy had come to now a thing or two.
# WER: 0.5652
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_25.wav
# Original: i don't always succeed for sometimes when i'm teaching or sewing i would rather be reading or writing but i try to deny myself and my father's approbation amply rewarded me for the privation
# Predicted:  i doubt all my sex for salarie in teaching or see-sawing i would rather be writing or reading i treat upon myself and my fores and my fores approdition and blear beech and ebony river it may fear
# WER: 0.8235
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_26.wav
# Original: the subject was a very noble one he described the most famous action in which the athenian people were ever engaged
# Predicted:  the subject was a very noban, said they, of the most famous achine in which the athenian sea people were ever engaged.
# WER: 0.3333
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_27.wav
# Original: the merganser had a crested head of iridescent green black a broad collar of lustrous white black back black and white wings white belly sides finely pencilled in black and white and a breast of rich chestnut red streaked with black
# Predicted:  the mergenzer hide a sea-crested head of eerie distinct green blackrack, of lustrous white blackrack back black, and white wings, white belly-sides, most thinly penciled, in blackrack and varbrose of ruch, chestnut, really strengthened with black.
# WER: 0.6341
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_28.wav
# Original: then as if satisfied of their safety the scout left his position and slowly entered the place
# Predicted:  then, as if satisfied of their saffety, the scout left.
# WER: 0.5882
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_29.wav
# Original: it is by no means always reliable almost everybody has at some time experienced the well known illusion that all that is happening now happened before at some time
# Predicted:  it is by no means almost everybody has at some time experienced the well-known notion that all that is happening now before.
# WER: 0.3448
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_30.wav
# Original: the hawk alighted on the dead branch and sat upright motionless as if surprised
# Predicted:  the hook alighted on the dead branch and sarsaprite motionals, as if surprised.
# WER: 0.3571
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_31.wav
# Original: been looking up tooms county
# Predicted:  been looking up tunes, can't he?
# WER: 0.6000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_32.wav
# Original: ojo examined this curious contrivance with wonder
# Predicted:  ojo examined this series' contravance with wonder.
# WER: 0.4286
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_33.wav
# Original: for it is a solid heavy handsome door and must once have been in the habit of shutting with a sonorous bang behind a liveried lackey who had just seen his master and mistress off the grounds in a carriage and pair
# Predicted:  for it is a solid heavy hansom dur and must on't have been in the habit of shotting with a sonorous bang behind with a reed-lead lakshy hoo he just seen his master and mistress off the grounds in a carriage and peer
# WER: 0.2381
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_34.wav
# Original: forgetting all their weariness they seized their candles and scurried through the house finding an occasional paper tucked away in some odd corner
# Predicted:  forgetting all there, wermick's day say to their candles unscurried through the house, finding an ace vision due fever-choked, away in same oddest
# WER: 0.6522
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_35.wav
# Original: this distinction is vital to the understanding of memory but it is not so easy to carry out in practice as it is to draw in theory
# Predicted:  this distinction is vital to the understanding of memory but it is not so easy to carry out and practice and to draw in theory
# WER: 0.1481
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_36.wav
# Original: socrates begins the timaeus with a summary of the republic
# Predicted:  socrates' bejans, the timurius, with a summary of the repu.
# WER: 0.4000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_37.wav
# Original: surface dust at least had been removed and the fine old furniture gave a hint of its real elegance and polish
# Predicted:  elsie's dust, at least, had been removed, and the fine old furniture gave a hint of its real allegiance and polish.
# WER: 0.2857
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_38.wav
# Original: i can perceive love clearly enough
# Predicted:  i can perceive love clearly in your ear.
# WER: 0.5000
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_39.wav
# Original: a route slightly less direct that's all
# Predicted:  a road slightly less direct, that's all.
# WER: 0.4286
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_40.wav
# Original: the squares of cotton sharp edged heavy were just about to burst to bolls
# Predicted:  the squares of cotton sharp, etched gear, just about to burst to balls.
# WER: 0.3571
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_41.wav
# Original: the analysis of knowledge will occupy us until the end of the thirteenth lecture and is the most difficult part of our whole enterprise
# Predicted:  the analysis of knowledge will, oskapius until, the end of the thirteenth lecture and is the most difficult part of our whole enterprise.
# WER: 0.2083
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_42.wav
# Original: on the mast already i see the light play of a lambent saint elmo's fire the outstretched sail catches not a breath of wind and hangs like a sheet of lead
# Predicted:  on the mast already i see the light play of a lambent ascent ilmo's fire. the outstretched sail catches, not a brythe of wind, and hangs like a sheet of lead.
# WER: 0.2258
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_43.wav
# Original: yes we are certainly i replied evasively but after we make a detour
# Predicted:  as we are, certainly, i replay it, a visibly bit, after we make a detour.
# WER: 0.6923
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_44.wav
# Original: i am not good enough for you and you must be kept from the contamination of too intimate society
# Predicted:  i am not good in you and you must be kept from the contamination of two intimate society.
# WER: 0.2105
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_45.wav
# Original: he had no occasion to delay for at the next instant a burst of cries filled the outer air and ran along the whole extent of the village
# Predicted:  he had no oesthesia to delay. re-extinct a burst of crease filled the outer air and raining along the whole extent of the village.
# WER: 0.3571
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_46.wav
# Original: what shall we do with the mingoes at the door they count six and this singer is as good as nothing
# Predicted:  what shall we do with the mingos? at the door they can't six and this and singer is as good as nothing.
# WER: 0.1905
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_47.wav
# Original: saturday after saturday comes round and i can have no hope of hearing your knock at the door and then being told that miss e is come oh dear
# Predicted:  tits-a-tick, things round, and i can have no hope of hiring, of faring your knuck at the door.
# WER: 0.7241
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_48.wav
# Original: the story of its evil influence came back to me and in my bewildered condition i wondered whether there was not some truth in what had been said
# Predicted:  the story of its evil eye came back too, and in my bewildered condition.
# WER: 0.6071
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_49.wav
# Original: they seem to be we are lost but i am not sure
# Predicted:  they seem to be wooed.
# WER: 0.6667
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_50.wav
# Original: and what through the left hand window
# Predicted:  and what through the left-hand window?
# WER: 0.4286
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_51.wav
# Original: the news circulated with the rapidity of lightning during its progress it kindled every variety of coquetry desire and wild ambition
# Predicted:  the news circulated with the rapidity of lightning during its progress that kindled every furryity of culture, desire and wild ambition.
# WER: 0.1905
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_52.wav
# Original: however remembering what you told me namely that you had commended the matter to a higher decision than ours and that you were resolved to submit with resignation to that decision whatever it might be i hold it my duty to yield also and to be silent it may be all for the best
# Predicted:  however, in what you told me, namely, that you had, came into the matter to a higher decision than uttered to a higher decision, to that decision, to that.
# WER: 0.7222
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_53.wav
# Original: now the object of this soliloquy is plain
# Predicted:  now the object of this soliloquy is plain.
# WER: 0.1250
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_54.wav
# Original: but first i will tell you that for many years i have longed for a servant to help me with the housework and to cook the meals and wash the dishes
# Predicted:  but first i will tell you that for many years i have longed for a servant to help me with the housework, and to cook the miles and white the dishes.
# WER: 0.1290
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_55.wav
# Original: her bearing was graceful and animated she led her son by the hand and before her walked two maids with wax lights and silver candlesticks
# Predicted:  her bearing was graspy, and any matted she chatter but gare. her sin by the hand, and before her walked two mites with wax lights and ye d'ever air candley sticks.
# WER: 0.5600
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_56.wav
# Original: but hawkeye who was too much occupied with his own thoughts to note the movement continued speaking more to himself than to his companion
# Predicted:  unbo is too old much a cuphead with his own thoughts to note the movement contained.
# WER: 0.6667
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_57.wav
# Original: gold is the most common metal in the land of oz and is used for many purposes because it is soft and pliable
# Predicted:  gold is the most common metal in the land of oz and is used for many purposes be it used, is soft and pliable.
# WER: 0.1304
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_58.wav
# Original: what was that
# Predicted:  what was that?
# WER: 0.3333
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_59.wav
# Original: but i would not speak at the time because i wanted to refresh my memory
# Predicted:  but i would not speak at the time because i wanted to refresh my memory.
# WER: 0.0667
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_60.wav
# Original: it seems the king will not consent to it
# Predicted:  it says axis the king will not consent to it.
# WER: 0.3333
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_61.wav
# Original: i want to get away from it all swoons
# Predicted:  i want to, in your way, from it all swoons.
# WER: 0.5556
# ----------------------------------------------------------------------------------------------------
# File: test/generated_audio_62.wav
# Original: well that may be true agreed margolotte but on the contrary a servant with too much brains is sure to become independent and high and mighty and feel above her work
# Predicted:  well, that may be true. margle, on the contrary, a servant, with too much brains is sure to become in jane. and meet ye, and meet ye, and meet ye, and feel a bore.
# WER: 0.6129
# ----------------------------------------------------------------------------------------------------
# Average WER: 0.4946

# %% [markdown]
# # Оценка сходства голосов (SECS) на Libri Speech test clean

# %%
# !python3 compute_secs.py
# Out:
# 2025-01-07 23:38:57.106347: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-07 23:38:57.127039: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-07 23:38:57.133012: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-07 23:38:58.380572: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:5849: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# File: 0
# Original: test/original_audio_0.wav
# Generated: test/generated_audio_0.wav
# SECS: 0.8841
# --------------------------------------------------
# File: 1
# Original: test/original_audio_1.wav
# Generated: test/generated_audio_1.wav
# SECS: 0.5483
# --------------------------------------------------
# File: 2
# Original: test/original_audio_2.wav
# Generated: test/generated_audio_2.wav
# SECS: 0.8922
# --------------------------------------------------
# File: 3
# Original: test/original_audio_3.wav
# Generated: test/generated_audio_3.wav
# SECS: 0.6445
# --------------------------------------------------
# File: 4
# Original: test/original_audio_4.wav
# Generated: test/generated_audio_4.wav
# SECS: 0.7746
# --------------------------------------------------
# File: 5
# Original: test/original_audio_5.wav
# Generated: test/generated_audio_5.wav
# SECS: 0.8617
# --------------------------------------------------
# File: 6
# Original: test/original_audio_6.wav
# Generated: test/generated_audio_6.wav
# SECS: 0.4609
# --------------------------------------------------
# File: 7
# Original: test/original_audio_7.wav
# Generated: test/generated_audio_7.wav
# SECS: 0.7222
# --------------------------------------------------
# File: 8
# Original: test/original_audio_8.wav
# Generated: test/generated_audio_8.wav
# SECS: 0.3300
# --------------------------------------------------
# File: 9
# Original: test/original_audio_9.wav
# Generated: test/generated_audio_9.wav
# SECS: 0.8122
# --------------------------------------------------
# File: 10
# Original: test/original_audio_10.wav
# Generated: test/generated_audio_10.wav
# SECS: 0.7074
# --------------------------------------------------
# File: 11
# Original: test/original_audio_11.wav
# Generated: test/generated_audio_11.wav
# SECS: 0.6062
# --------------------------------------------------
# File: 12
# Original: test/original_audio_12.wav
# Generated: test/generated_audio_12.wav
# SECS: 0.6831
# --------------------------------------------------
# File: 13
# Original: test/original_audio_13.wav
# Generated: test/generated_audio_13.wav
# SECS: 0.2782
# --------------------------------------------------
# File: 14
# Original: test/original_audio_14.wav
# Generated: test/generated_audio_14.wav
# SECS: 0.7984
# --------------------------------------------------
# File: 15
# Original: test/original_audio_15.wav
# Generated: test/generated_audio_15.wav
# SECS: 0.5003
# --------------------------------------------------
# File: 16
# Original: test/original_audio_16.wav
# Generated: test/generated_audio_16.wav
# SECS: 0.7788
# --------------------------------------------------
# File: 17
# Original: test/original_audio_17.wav
# Generated: test/generated_audio_17.wav
# SECS: 0.5420
# --------------------------------------------------
# File: 18
# Original: test/original_audio_18.wav
# Generated: test/generated_audio_18.wav
# SECS: 0.6982
# --------------------------------------------------
# File: 19
# Original: test/original_audio_19.wav
# Generated: test/generated_audio_19.wav
# SECS: 0.7989
# --------------------------------------------------
# File: 20
# Original: test/original_audio_20.wav
# Generated: test/generated_audio_20.wav
# SECS: 0.6704
# --------------------------------------------------
# File: 21
# Original: test/original_audio_21.wav
# Generated: test/generated_audio_21.wav
# SECS: 0.8235
# --------------------------------------------------
# File: 22
# Original: test/original_audio_22.wav
# Generated: test/generated_audio_22.wav
# SECS: 0.4841
# --------------------------------------------------
# File: 23
# Original: test/original_audio_23.wav
# Generated: test/generated_audio_23.wav
# SECS: 0.8615
# --------------------------------------------------
# File: 24
# Original: test/original_audio_24.wav
# Generated: test/generated_audio_24.wav
# SECS: 0.7842
# --------------------------------------------------
# File: 25
# Original: test/original_audio_25.wav
# Generated: test/generated_audio_25.wav
# SECS: 0.8506
# --------------------------------------------------
# File: 26
# Original: test/original_audio_26.wav
# Generated: test/generated_audio_26.wav
# SECS: 0.8251
# --------------------------------------------------
# File: 27
# Original: test/original_audio_27.wav
# Generated: test/generated_audio_27.wav
# SECS: 0.5965
# --------------------------------------------------
# File: 28
# Original: test/original_audio_28.wav
# Generated: test/generated_audio_28.wav
# SECS: 0.3811
# --------------------------------------------------
# File: 29
# Original: test/original_audio_29.wav
# Generated: test/generated_audio_29.wav
# SECS: 0.5715
# --------------------------------------------------
# File: 30
# Original: test/original_audio_30.wav
# Generated: test/generated_audio_30.wav
# SECS: 0.6708
# --------------------------------------------------
# File: 31
# Original: test/original_audio_31.wav
# Generated: test/generated_audio_31.wav
# SECS: 0.6905
# --------------------------------------------------
# File: 32
# Original: test/original_audio_32.wav
# Generated: test/generated_audio_32.wav
# SECS: 0.6270
# --------------------------------------------------
# File: 33
# Original: test/original_audio_33.wav
# Generated: test/generated_audio_33.wav
# SECS: 0.8261
# --------------------------------------------------
# File: 34
# Original: test/original_audio_34.wav
# Generated: test/generated_audio_34.wav
# SECS: 0.4565
# --------------------------------------------------
# File: 35
# Original: test/original_audio_35.wav
# Generated: test/generated_audio_35.wav
# SECS: 0.5430
# --------------------------------------------------
# File: 36
# Original: test/original_audio_36.wav
# Generated: test/generated_audio_36.wav
# SECS: 0.7417
# --------------------------------------------------
# File: 37
# Original: test/original_audio_37.wav
# Generated: test/generated_audio_37.wav
# SECS: 0.3183
# --------------------------------------------------
# File: 38
# Original: test/original_audio_38.wav
# Generated: test/generated_audio_38.wav
# SECS: 0.2842
# --------------------------------------------------
# File: 39
# Original: test/original_audio_39.wav
# Generated: test/generated_audio_39.wav
# SECS: 0.6938
# --------------------------------------------------
# File: 40
# Original: test/original_audio_40.wav
# Generated: test/generated_audio_40.wav
# SECS: 0.7922
# --------------------------------------------------
# File: 41
# Original: test/original_audio_41.wav
# Generated: test/generated_audio_41.wav
# SECS: 0.5526
# --------------------------------------------------
# File: 42
# Original: test/original_audio_42.wav
# Generated: test/generated_audio_42.wav
# SECS: 0.5597
# --------------------------------------------------
# File: 43
# Original: test/original_audio_43.wav
# Generated: test/generated_audio_43.wav
# SECS: 0.8074
# --------------------------------------------------
# File: 44
# Original: test/original_audio_44.wav
# Generated: test/generated_audio_44.wav
# SECS: 0.7929
# --------------------------------------------------
# File: 45
# Original: test/original_audio_45.wav
# Generated: test/generated_audio_45.wav
# SECS: 0.3417
# --------------------------------------------------
# File: 46
# Original: test/original_audio_46.wav
# Generated: test/generated_audio_46.wav
# SECS: 0.3169
# --------------------------------------------------
# File: 47
# Original: test/original_audio_47.wav
# Generated: test/generated_audio_47.wav
# SECS: 0.7694
# --------------------------------------------------
# File: 48
# Original: test/original_audio_48.wav
# Generated: test/generated_audio_48.wav
# SECS: 0.3503
# --------------------------------------------------
# File: 49
# Original: test/original_audio_49.wav
# Generated: test/generated_audio_49.wav
# SECS: 0.5743
# --------------------------------------------------
# File: 50
# Original: test/original_audio_50.wav
# Generated: test/generated_audio_50.wav
# SECS: 0.7942
# --------------------------------------------------
# File: 51
# Original: test/original_audio_51.wav
# Generated: test/generated_audio_51.wav
# SECS: 0.4852
# --------------------------------------------------
# File: 52
# Original: test/original_audio_52.wav
# Generated: test/generated_audio_52.wav
# SECS: 0.8608
# --------------------------------------------------
# File: 53
# Original: test/original_audio_53.wav
# Generated: test/generated_audio_53.wav
# SECS: 0.5132
# --------------------------------------------------
# File: 54
# Original: test/original_audio_54.wav
# Generated: test/generated_audio_54.wav
# SECS: 0.8440
# --------------------------------------------------
# File: 55
# Original: test/original_audio_55.wav
# Generated: test/generated_audio_55.wav
# SECS: 0.6909
# --------------------------------------------------
# File: 56
# Original: test/original_audio_56.wav
# Generated: test/generated_audio_56.wav
# SECS: 0.3227
# --------------------------------------------------
# File: 57
# Original: test/original_audio_57.wav
# Generated: test/generated_audio_57.wav
# SECS: 0.6994
# --------------------------------------------------
# File: 58
# Original: test/original_audio_58.wav
# Generated: test/generated_audio_58.wav
# SECS: 0.3077
# --------------------------------------------------
# File: 59
# Original: test/original_audio_59.wav
# Generated: test/generated_audio_59.wav
# SECS: 0.8092
# --------------------------------------------------
# File: 60
# Original: test/original_audio_60.wav
# Generated: test/generated_audio_60.wav
# SECS: 0.2915
# --------------------------------------------------
# File: 61
# Original: test/original_audio_61.wav
# Generated: test/generated_audio_61.wav
# SECS: 0.5614
# --------------------------------------------------
# File: 62
# Original: test/original_audio_62.wav
# Generated: test/generated_audio_62.wav
# SECS: 0.8619
# --------------------------------------------------
# Average SECS: 0.6337

# %% [markdown]
# # Итоги
#
# | Датасет \ метрики           | WER    | UTMOS  | SECS   |
# |-----------------------------|--------|--------|--------|
# | **LibriSpeech Test Clean**  | 0.4946 | 4.1036 | 0.6337 |
# | **Jenny**                   | 0.2074 | 4.1682 | 0.9356 |
#
#
# Бенчмарки на датасете **LibriSpeech Test Clean** получились хуже, что во-первых, возможно из-за того, что аудио из датасета **Jenny** использовалось для трейна, во-вторых: для генерации аудио из датасета **LibriSpeech Test Clean**, возможно, использовался не сильно релевантный промт.
